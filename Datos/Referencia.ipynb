# %%
import nltk

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\pablo\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
from nltk.corpus import twitter_samples

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pablo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

print(tweet_tokens[0])
# Out:
# ['#FollowFriday', '@France_Inte', '@PKuchly57', '@Milipol_Paris', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':)']

# %%
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pablo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\pablo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.tag import pos_tag
from nltk.corpus import twitter_samples

tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
print(pos_tag(tweet_tokens[0]))
# Out:
# [('#FollowFriday', 'JJ'), ('@France_Inte', 'NNP'), ('@PKuchly57', 'NNP'), ('@Milipol_Paris', 'NNP'), ('for', 'IN'), ('being', 'VBG'), ('top', 'JJ'), ('engaged', 'VBN'), ('members', 'NNS'), ('in', 'IN'), ('my', 'PRP$'), ('community', 'NN'), ('this', 'DT'), ('week', 'NN'), (':)', 'NN')]

# %%
from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer

def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

print(lemmatize_sentence(tweet_tokens[0]))
# Out:
# ['#FollowFriday', '@France_Inte', '@PKuchly57', '@Milipol_Paris', 'for', 'be', 'top', 'engage', 'member', 'in', 'my', 'community', 'this', 'week', ':)']

# %%
import re, string

def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pablo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

print(remove_noise(tweet_tokens[0], stop_words))
# Out:
# ['#followfriday', 'top', 'engage', 'member', 'community', 'week', ':)']

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

for tokens in negative_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
print(positive_tweet_tokens[500])
print(positive_cleaned_tokens_list[500])
# Out:
# ['Dang', 'that', 'is', 'some', 'rad', '@AbzuGame', '#fanart', '!', ':D', 'https://t.co/bI8k8tb9ht']
# ['dang', 'rad', '#fanart', ':d']

# %%
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

all_pos_words = get_all_words(positive_cleaned_tokens_list)
print(positive_cleaned_tokens_list)
# Out:
# [['#followfriday', 'top', 'engage', 'member', 'community', 'week', ':)'], ['hey', 'james', 'odd', ':/', 'please', 'call', 'contact', 'centre', '02392441234', 'able', 'assist', ':)', 'many', 'thanks'], ['listen', 'last', 'night', ':)', 'bleed', 'amazing', 'track', 'scotland'], ['congrats', ':)'], ['yeaaaah', 'yippppy', 'accnt', 'verify', 'rqst', 'succeed', 'get', 'blue', 'tick', 'mark', 'fb', 'profile', ':)', '15', 'day'], ['one', 'irresistible', ':)', '#flipkartfashionfriday'], ['like', 'keep', 'lovely', 'customer', 'wait', 'long', 'hope', 'enjoy', 'happy', 'friday', 'lwwf', ':)'], ['second', 'thought', '’', 'enough', 'time', 'dd', ':)', 'new', 'short', 'enter', 'system', 'sheep', 'must', 'buy'], ['jgh', 'go', 'bayan', ':d', 'bye'], ['act', 'mischievousness', 'call', 'etl', 'layer', 'in-house', 'warehouse', 'app', 'katamari', 'well', '…', 'name', 'imply', ':p'], ['#followfriday', 'top', 'influencers', 'community', 'week', ':)'], ['love', 'big', '...', 'juicy', '...', 'selfies', ':)'], ['follow', 'follow', 'u', 'back', ':)'], ['perfect', 'already', 'know', "what's", 'wait', ':)'], ['great', 'new', 'opportunity', 'junior', 'triathletes', 'age', '12', '13', 'gatorade', 'series', 'get', 'entry', ':)'], ['laying', 'greeting', 'card', 'range', 'print', 'today', 'love', 'job', ':-)'], ["friend's", 'lunch', '...', 'yummmm', ':)', '#nostalgia', '#tbs', '#ku'], ['id', 'conflict', 'thanks', 'help', ':d', "here's", 'screenshot', 'work'], ['hi', 'liv', ':)'], ['hello', 'need', 'know', 'something', 'u', 'fm', 'twitter', '—', 'sure', 'thing', ':)', 'dm', 'x'], ['#followfriday', 'top', 'new', 'follower', 'community', 'week', ':)'], ["i've", 'hear', 'four', 'seasons', 'pretty', 'dope', 'penthouse', 'obvs', '#gobigorgohome', 'fun', "y'all", ':)'], ['yeah', 'suppose', 'lol', 'chat', 'bit', 'x', ':)'], ['hello', ':)', 'get', 'youth', 'job', 'opportunities', 'follow'], ['💅', '🏽', '💋', ':)', 'see', 'year'], ['thank', ':-)'], ['hope', 'rest', 'night', 'go', 'quickly', '...', 'bed', '...', 'get', 'music', 'fix', 'time', 'dream', ':)'], ['spiritual', 'ritual', 'festival', 'népal', 'beginning', 'line-up', ':)', 'leave', 'line-up', 'see', '...'], ['hey', 'sarah', 'send', 'us', 'email', 'bitsy.com', "we'll", 'help', 'asap', ':)'], ['lols', ':d'], ['kik', 'hatessuce', '32429', '#kik', '#kikme', '#lgbt', '#tinder', '#nsfw', '#akua', '#cumshot', ':)'], ['come', 'house', ':)'], ['#nsn_supplements', 'effective', 'press', 'release', 'distribution', 'result', ':)', 'link', 'remove', '#pressrelease', '#newsdistribution'], ['hi', 'bam', 'follow', 'bestfriend', 'love', 'lot', ':)', 'see', 'warsaw', '<3', 'love', '<3', 'x46'], ['everyone', 'watch', 'documentary', 'earthlings', 'youtube', ':-)'], ['follow', 'follow', 'u', 'back', ':)'], ['#followfriday', 'top', 'support', 'community', 'week', ':)'], ['buuuuuuuut', 'oh', 'well', ':-)'], ['look', 'forward', 'visit', 'next', 'week', '#letsgetmessy', 'jo', ':-)'], ['make', 'u', 'feel', 'good', 'never', 'see', 'anyone', 'kpop', 'flesh', ':d'], ['good', 'girl', 'best', 'wish', ':-)'], ['great', 'enough', 'reason', 'listen', 'one', 'epic', 'soundtrack', ':d'], ['thank', 'shout', 'great', 'friday', ':)'], ['add', 'video', 'playlist', 'im', 'back', 'twitch', 'today', 'go', 'league', ':)', '1', '4'], ['would', 'love', 'see', 'dear', '#jordan', ':)', 'wait', ':)'], ['oh', 'okay', ':d', 'thanks'], ['like', 'fake', 'gameplays', ';)', 'haha', 'im', 'kidding', 'im', 'kidding', 'good', 'stuff', ':)'], ['yeah', 'exactly', ':)'], ['new', 'product', 'line', '#etsy', 'shop', 'check', ':)', '#boxroomcrafts'], ['hope', 'vacation', 'go', 'great', ':d'], ['rechargeable', 'normally', 'come', 'charger', 'u', 'buy', ':)'], ['#followfriday', 'top', 'engage', 'member', 'community', 'week', ':)'], ['well', 'asleep', 'one', 'talk', 'sooo', 'someone', 'text', ':)'], ['yes', 'suppose', 'bet', "he'll", 'blue', 'fit', 'hear', 'speech', 'today', 'pity', ':-)'], ['green', 'garden', 'midnight', 'sun', 'beautiful', 'canal', 'dasvidaniya', 'till', 'next', ...

# %%
from nltk import FreqDist

freq_dist_pos = FreqDist(all_pos_words)
print(freq_dist_pos.most_common(10))
# Out:
# [(':)', 3691), (':-)', 701), (':d', 658), ('thanks', 388), ('follow', 357), ('love', 333), ('...', 290), ('good', 283), ('get', 263), ('thank', 253)]

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
import random

positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:7000]
test_data = dataset[7000:]

print(dataset)
# Out:
# [({'let': True, 'know': True, 'hear': True, 'anything': True, ':)': True, 'xx': True}, 'Positive'), ({'thanks': True, 'wish': True, ':)': True}, 'Positive'), ({'movie': True, 'marathon': True, 'anyonneeee': True, ':(': True, 'loner': True, 'af': True}, 'Negative'), ({'miss': True, 'chel': True, ':(': True}, 'Negative'), ({"here's": True, '★': True, 'review': True, 'phew': True, "we're": True, 'literally': True, 'overwhelm': True, ':)': True}, 'Positive'), ({"can't": True, 'sleeeep': True, ':(': True}, 'Negative'), ({'date': True, 'yet': True, ':(': True}, 'Negative'), ({'point': True, 'yolo': True, 'sort': True, 'die': True, 'lactose': True, '...': True, 'ugh': True, 'like': True, '3': True, 'month': True, 'pregnant': True, 'bloating': True, ':(': True}, 'Negative'), ({'bless': True, 'friday': True, 'everyone': True, ':)': True}, 'Positive'), ({'im': True, 'tempt': True, 'stream': True, 'screenshot': True, 'sjkaos': True, ':(': True}, 'Negative'), ({"he's": True, 'cute': True, ':(': True}, 'Negative'), ({'thank': True, 'amazing': True, 'day': True, ':-)': True}, 'Positive'), ({'fback': True, ':)': True}, 'Positive'), ({'#flipkartfashionfriday': True, 'multicolored': True, 'maxi': True, 'dress': True, 'pair': True, 'wid': True, 'wedges': True, 'make': True, 'ur': True, 'life': True, 'bright': True, 'colorful': True, ':)': True}, 'Positive'), ({'hello': True, 'info': True, 'possible': True, 'interest': True, 'jonathas': True, 'close': True, 'join': True, 'betis': True, ':(': True}, 'Negative'), ({'hi': True, 'make': True, 'change': True, 'design': True, 'hope': True, 'like': True, ':)': True}, 'Positive'), ({'lucky': True, ':(': True, 'feel': True, 'hungry': True, 'wanna': True, 'get': True, 'bed': True, 'either': True, 'gotta': True, 'wait': True, 'mañana': True}, 'Negative'), ({'great': True, 'day': True, 'hunny': True, ':)': True}, 'Positive'), ({'guy': True, 'say': True, 'omegle': True, '😁': True, 'could': True, 'use': True, 'google': True, ':)': True, "that's": True, "i'm": True}, 'Positive'), ({'strange': True, "kareena's": True, 'fans': True, 'knowing': True, ':)': True}, 'Positive'), ({'nia': True, 'want': True, 'meet': True, ':(': True}, 'Negative'), ({'hahahaha': True, 'way': True, ':p': True, 'must': True, 'wear': True, 'ah': True, 'school': True, 'uniform': True}, 'Positive'), ({'free': True, 'twitter': True, ':(': True}, 'Negative'), ({'spoile': True, ':)': True}, 'Positive'), ({'kik': True, 'guy': True, 'shek': True, '609': True, '#kik': True, '#kikgirl': True, '#hot': True, '#likeforlike': True, '#horny': True, '#goodmusic': True, '#mugshot': True, ':(': True}, 'Negative'), ({'still': True, 'really': True, 'like': True, 'chipotle': True, 'chick-fil-a': True, 'stole': True, 'heart': True, ':(': True}, 'Negative'), ({"can't": True, 'charge': True, 'pad': True, 'toffee': True, 'though': True, 'tried': True, 'switch': True, 'someone': True, 'bison': True, 'never': True, 'get': True, 'back': True, ':(': True}, 'Negative'), ({'tag': True, '♡': True, "i'm": True, 'sorry': True, 'lot': True, 'music': True, 'prolly': True, 'know': True, 'half': True, ':(': True, 'also': True}, 'Negative'), ({'good': True, 'flight': True, ':)': True}, 'Positive'), ({'rt': True, 'spree': True, 'atm': True, ':)': True}, 'Positive'), ({'hiya': True, 'email': True, 'web': True, 'exec': True, 'loryn.good-chamber.co.uk': True, 'able': True, 'help': True, ':)': True}, 'Positive'), ({'combine': True, 'three': True, 'add': True, 'bit': True, 'asian': True, 'u': True, 'get': True, 'truly': True, ':)': True}, 'Positive'), ({'haha': True, 'indirecting': True, 'best': True, 'friend': True, ':)': True}, 'Positive'), ({'srsly': True, 'u': True, ':(': True}, 'Negative'), ({'welcome': True, ':)': True}, 'Positive'), ({'chaerin': True, 'unnie': True}, 'Positive'), ({'thank': True, 'amazing': True, 'job': True, ':)': True}, 'Positive'), ({'traffic': True, ':-(': True}, 'Negative'), ({'musical': True, 'human': True, 'genius': True, 'stromae': True, ':)': True} ...

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.9946666666666667
# Most Informative Features
#                       :) = True           Positi : Negati =   1000.5 : 1.0
#                      sad = True           Negati : Positi =     21.0 : 1.0
#                 follower = True           Positi : Negati =     19.9 : 1.0
#               appreciate = True           Positi : Negati =     18.1 : 1.0
#                     glad = True           Positi : Negati =     18.1 : 1.0
#                      x15 = True           Negati : Positi =     17.2 : 1.0
#                     blog = True           Positi : Negati =     16.7 : 1.0
#                 followed = True           Negati : Positi =     16.2 : 1.0
#                     damn = True           Negati : Positi =     15.9 : 1.0
#                community = True           Positi : Negati =     15.4 : 1.0
# None

# %%
from nltk.tokenize import word_tokenize

custom_tweet = "I ordered just once from TerribleCo, they screwed up, never used the app again."

custom_tokens = remove_noise(word_tokenize(custom_tweet))

print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# Positive

# %%
custom_tweet = 'Congrats #SportStar on your 7th best goal from last season winning goal of the year :) #Baller #Topbin #oneofmanyworldies'
custom_tokens = remove_noise(word_tokenize(custom_tweet))

print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# Positive

# %%
custom_tweet = 'Thank you for sending my baggage to CityX and flying me to CityY at the same time. Brilliant service. #thanksGenericAirline'
custom_tokens = remove_noise(word_tokenize(custom_tweet))
print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# Positive
